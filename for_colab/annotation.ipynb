# %% [markdown]
# # 드라이브 연결하기

# %%
# annotation과 image 디렉토리 설정. annotation디렉토리에 있는 파일 확인. 
import os
from pathlib import Path

HOME_DIR = str(Path.home())
print(HOME_DIR)

ANNO_DIR = '/content/drive/MyDrive/capstone/train_image/annotation' 
IMAGE_DIR = '/content/drive/MyDrive/capstone/train_image/image'

files = os.listdir(ANNO_DIR)
print('파일 개수는:',len(files))  # 200개
print(files)  # Dicrectory에 있는 파일 이름 전부가 list 변수에 저장된다.
# Out:
# /root
# 파일 개수는: 1470
# ['aug_23.xml', 'aug_1034.xml', 'aug_1033.xml', 'aug_1030.xml', 'aug_1031.xml', 'aug_1029.xml', 'aug_1028.xml', 'aug_1027.xml', 'aug_1026.xml', 'aug_1024.xml', 'aug_1022.xml', 'aug_1021.xml', 'aug_1016.xml', 'aug_1015.xml', 'aug_1019.xml', 'aug_18.xml', 'aug_20.xml', 'aug_16.xml', 'aug_15.xml', 'aug_1012.xml', 'aug_1010.xml', 'aug_1004.xml', 'aug_1009.xml', 'aug_1005.xml', 'aug_1006.xml', 'aug_31.xml', 'aug_13.xml', 'aug_12.xml', 'aug_1.xml', 'aug_29.xml', 'aug_25.xml', 'aug_1043.xml', 'aug_1042.xml', 'aug_1044.xml', 'aug_1041.xml', 'aug_1040.xml', 'aug_1039.xml', 'aug_1038.xml', 'aug_1037.xml', 'aug_1036.xml', 'aug_1035.xml', 'aug_1055.xml', 'aug_1054.xml', 'aug_1053.xml', 'aug_1052.xml', 'aug_1051.xml', 'aug_1050.xml', 'aug_1049.xml', 'aug_1047.xml', 'aug_1046.xml', 'aug_1045.xml', 'aug_BikesHelmets23.xml', 'aug_BikesHelmets5.xml', 'aug_BikesHelmets13.xml', 'aug_BikesHelmets4.xml', 'aug_BikesHelmets1.xml', 'aug_2005.xml', 'aug_2004.xml', 'aug_2003.xml', 'aug_2002.xml', 'aug_2001.xml', 'aug_1059.xml', 'aug_1057.xml', 'aug_1058.xml', 'aug_1056.xml', 'aug_BikesHelmets122.xml', 'aug_BikesHelmets121.xml', 'aug_BikesHelmets119.xml', 'aug_BikesHelmets111.xml', 'aug_BikesHelmets109.xml', 'aug_BikesHelmets92.xml', 'aug_BikesHelmets90.xml', 'aug_BikesHelmets83.xml', 'aug_BikesHelmets77.xml', 'aug_BikesHelmets71.xml', 'aug_BikesHelmets62.xml', 'aug_BikesHelmets60.xml', 'aug_BikesHelmets61.xml', 'aug_BikesHelmets53.xml', 'aug_BikesHelmets51.xml', 'aug_BikesHelmets46.xml', 'aug_BikesHelmets34.xml', 'aug_BikesHelmets29.xml', 'aug_BikesHelmets27.xml', 'aug_BikesHelmets225.xml', 'aug_BikesHelmets210.xml', 'aug_BikesHelmets202.xml', 'aug_BikesHelmets212.xml', 'aug_BikesHelmets201.xml', 'aug_BikesHelmets187.xml', 'aug_BikesHelmets196.xml', 'aug_BikesHelmets183.xml', 'aug_BikesHelmets172.xml', 'aug_BikesHelmets167.xml', 'aug_BikesHelmets158.xml', 'aug_BikesHelmets133.xml', 'aug_BikesHelmets289.xml', 'aug_BikesHelmets288.xml', 'aug_BikesHelmets284.xml', 'aug_BikesHelmets280.xml', 'aug_BikesHelmets273.xml', 'aug_BikesHelmets268.xml', 'aug_BikesHelmets263.xml', 'aug_BikesHelmets251.xml', 'aug_BikesHelmets246.xml', 'aug_BikesHelmets245.xml', 'aug_BikesHelmets242.xml', 'aug_BikesHelmets238.xml', 'aug_BikesHelmets229.xml', 'aug_BikesHelmets401.xml', 'aug_BikesHelmets396.xml', 'aug_BikesHelmets392.xml', 'aug_BikesHelmets391.xml', 'aug_BikesHelmets380.xml', 'aug_BikesHelmets390.xml', 'aug_BikesHelmets364.xml', 'aug_BikesHelmets368.xml', 'aug_BikesHelmets352.xml', 'aug_BikesHelmets343.xml', 'aug_BikesHelmets335.xml', 'aug_BikesHelmets319.xml', 'aug_BikesHelmets318.xml', 'aug_BikesHelmets305.xml', 'aug_BikesHelmets291.xml', 'aug_BikesHelmets453.xml', 'aug_BikesHelmets451.xml', 'aug_BikesHelmets445.xml', 'aug_BikesHelmets438.xml', 'aug_BikesHelmets441.xml', 'aug_BikesHelmets434.xml', 'aug_BikesHelmets426.xml', 'aug_BikesHelmets427.xml', 'aug_BikesHelmets423.xml', 'aug_BikesHelmets413.xml', 'aug_BikesHelmets418.xml', 'aug_BikesHelmets412.xml', 'aug_BikesHelmets563.xml', 'aug_BikesHelmets549.xml', 'aug_BikesHelmets538.xml', 'aug_BikesHelmets535.xml', 'aug_BikesHelmets533.xml', 'aug_BikesHelmets522.xml', 'aug_BikesHelmets512.xml', 'aug_BikesHelmets508.xml', 'aug_BikesHelmets477.xml', 'aug_BikesHelmets473.xml', 'aug_BikesHelmets468.xml', 'aug_BikesHelmets467.xml', 'aug_BikesHelmets458.xml', 'aug_BikesHelmets642.xml', 'aug_BikesHelmets639.xml', 'aug_BikesHelmets630.xml', 'aug_BikesHelmets629.xml', 'aug_BikesHelmets612.xml', 'aug_BikesHelmets607.xml', 'aug_BikesHelmets590.xml', 'aug_BikesHelmets587.xml', 'aug_BikesHelmets588.xml', 'aug_BikesHelmets585.xml', 'aug_BikesHelmets575.xml', 'aug_BikesHelmets579.xml', 'aug_BikesHelmets570.xml', 'aug_BikesHelmets572.xml', 'aug_BikesHelmets567.xml', 'aug_BikesHelmets683.xml', 'aug_BikesHelmets675.xml', 'aug_BikesHelmets666.xml', 'aug_BikesHelmets659.xml', 'aug_BikesHelmets661.xml', 'aug_BikesHelmets658.xml', 'aug_BikesHelmets655.xml', 'aug_BikesHelmets650.xml', 'aug_KakaoTalk_20220324_190256213_01.xml', 'aug_KakaoTalk_20 ...

# %%
#multiclass labeling 위함
det = {}
det['Helmet'] = 0
det['NonHelmet']=1

import glob
import xml.etree.ElementTree as ET

def xml_to_csv(path, output_filename):
    """
    path : annotation Detectory
    filename : ouptut file name
    """
    xml_list = []
    # xml 확장자를 가진 모든 파일의 절대 경로로 xml_file할당. 
    with open(output_filename, "w") as train_csv_file:
        for xml_file in glob.glob(path + '/*.xml'):
            # path에 있는 xml파일중 하나 하나를 가져온다. 
            tree = ET.parse(xml_file) 
            root = tree.getroot()
            # 파일내에 있는 모든 object Element를 찾음. 
            full_image_name = os.path.join(IMAGE_DIR, root.find('filename').text)
            value_str_list = ' '
            # find all <object>인것 다 찾는다
            for obj in root.findall('object'): 
                xmlbox = obj.find('bndbox')
                x1 = int(xmlbox.find('xmin').text)
                y1 = int(xmlbox.find('ymin').text)
                x2 = int(xmlbox.find('xmax').text)
                y2 = int(xmlbox.find('ymax').text)
                # helmet, nonhelmet
                label = obj.find('name').text

                if label in det:
                    class_id = det[label]
                else:
                    class_id = -1

                #class_id = 0
                value_str = ('{0},{1},{2},{3},{4}').format(x1, y1, x2, y2, class_id)
                value_str_list = value_str_list+value_str+' ' 
                # box1 box2 ......
                # object별 정보를 tuple형태로 object_list에 저장. 
            train_csv_file.write(full_image_name+' '+ value_str_list+'\n') # image_file_path box1 box2 ... boxN \n ... image_file_path
        # xml file 찾는 for loop 종료 

xml_to_csv(ANNO_DIR, os.path.join(ANNO_DIR,'helmet_anno.csv'))
print(os.path.join(ANNO_DIR,'helmet_anno.csv'))
# Out:
# /content/drive/MyDrive/capstone/train_image/annotation/helmet_anno.csv
